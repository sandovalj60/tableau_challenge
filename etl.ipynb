# %%
# import dependencies
import pandas as pd

# %%
# set the path file and read

path_1 = 'data\JC-202110-citibike-tripdata.csv'
path_2 = 'data\JC-202210-citibike-tripdata.csv'


df_1 = pd.read_csv(path_1)
df_2 = pd.read_csv(path_2)

df_1
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      1F77B1214EC26C33  electric_bike  2021-10-06 18:56:43
# 1      2C4DBFEC79FAE712   classic_bike  2021-10-11 20:37:02
# 2      3C533F406407D755   classic_bike  2021-10-30 20:19:06
# 3      D46E9259B84BE225   classic_bike  2021-10-22 18:33:03
# 4      0A6B5D4CC23FC8E5   classic_bike  2021-10-07 16:12:17
# ...                 ...            ...                  ...
# 88757  7975856DA64B043C   classic_bike  2021-10-13 17:26:56
# 88758  498F51A289260C9D   classic_bike  2021-10-20 08:32:28
# 88759  91959063E5BD10DF   classic_bike  2021-10-28 07:17:32
# 88760  CAD61AD888295639   classic_bike  2021-10-15 07:19:00
# 88761  995661CEA59CEE88   classic_bike  2021-10-07 09:14:21
#
#                   ended_at      start_station_name start_station_id  \
# 0      2021-10-06 19:47:05         McGinley Square            JC055
# 1      2021-10-11 20:47:31  Clinton St & Newark St            HB409
# ...

# %%
df_2
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      705B9BE3434233E7   classic_bike  2022-10-27 11:20:23
# 1      660EE8D1E1D21D0F   classic_bike  2022-10-23 22:56:06
# 2      81CCDC472990FD62  electric_bike  2022-10-30 17:47:15
# 3      155ABDCC56D1E9D3   classic_bike  2022-10-11 17:28:53
# 4      47DB1136D49EDA96   classic_bike  2022-10-16 22:22:34
# ...                 ...            ...                  ...
# 89553  29D7126C0D802E5B  electric_bike  2022-10-08 07:38:41
# 89554  D50B41C904A7C5B3  electric_bike  2022-10-27 08:56:15
# 89555  B4240A4EEB9DB4D5   classic_bike  2022-10-23 08:28:34
# 89556  5F76013D50A68AA7   classic_bike  2022-10-12 12:19:26
# 89557  D47114548D40A009   classic_bike  2022-10-14 08:46:52
#
#                   ended_at     start_station_name start_station_id  \
# 0      2022-10-27 11:55:47          Grove St PATH            JC005
# 1      2022-10-23 23:09:03          Grove St PATH            JC005
# ...

# %%
# concat both df's
new_df = pd.concat([df_1,df_2])

# %%
# check the new df to make sure concat appropriately
new_df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      1F77B1214EC26C33  electric_bike  2021-10-06 18:56:43
# 1      2C4DBFEC79FAE712   classic_bike  2021-10-11 20:37:02
# 2      3C533F406407D755   classic_bike  2021-10-30 20:19:06
# 3      D46E9259B84BE225   classic_bike  2021-10-22 18:33:03
# 4      0A6B5D4CC23FC8E5   classic_bike  2021-10-07 16:12:17
# ...                 ...            ...                  ...
# 89553  29D7126C0D802E5B  electric_bike  2022-10-08 07:38:41
# 89554  D50B41C904A7C5B3  electric_bike  2022-10-27 08:56:15
# 89555  B4240A4EEB9DB4D5   classic_bike  2022-10-23 08:28:34
# 89556  5F76013D50A68AA7   classic_bike  2022-10-12 12:19:26
# 89557  D47114548D40A009   classic_bike  2022-10-14 08:46:52
#
#                   ended_at      start_station_name start_station_id  \
# 0      2021-10-06 19:47:05         McGinley Square            JC055
# 1      2021-10-11 20:47:31  Clinton St & Newark St            HB409
# ...

# %%
# save new merged df
new_df.to_csv('data/2021-2022_df.csv')
